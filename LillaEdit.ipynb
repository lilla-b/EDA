# %%
#Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import seaborn as sns

# Import API key
from api_keys import api_key

# %%
import json

# adding api_key to base url to obtain FDA information 
base_url = "https://api.fda.gov/drug/event.json?api_key=" + api_key

# changing the output to json 
req = requests.get(base_url)
data = req.json()

#print the data to show something is returned
#print(data)

# %%
#creating empty dictionary to add data to
cats_data = {'gender':[],
                'age':[],
                'weight':[],
                'breed':[],
                'drug':[],
                'outcome':[],
                'date_in':[]}
#verifying search on Cat species and positioning on breed work correctly 
base_url = "https://api.fda.gov/animalandveterinary/event.json?search=animal.species=Cat+animal.breed.breed_component='Domestic Shorthair'"
req = requests.get(base_url)
data = req.json()

#add 1 row to the cats_data dictionary with information extracted - limit for this api call is 1 result
cats_data['gender'].append(data['results'][0]['animal']['gender'])
cats_data['age'].append(data['results'][0]['animal']['age']['min'])
cats_data['weight'].append(data['results'][0]['animal']['weight']['min'])
cats_data['breed'].append(data['results'][0]['animal']['breed']['breed_component'])
cats_data['drug'].append(data['results'][0]['drug'][0]['active_ingredients'][0]['name'])
cats_data['outcome'].append(data['results'][0]['outcome'][0]['medical_status'])
cats_data['date_in'].append(data['results'][0]['original_receive_date'])

print(cats_data)
# Out:
# {'gender': ['Male'], 'age': ['10.00'], 'weight': ['6.350'], 'breed': ['Domestic Shorthair'], 'drug': ['Spinosad'], 'outcome': ['Recovered/Normal'], 'date_in': ['20170508']}

# %%
# Since this url returns only the first match, we are using a loop to skip entries and pick up another one - otherwise the 
# same one is returned every time.
# Returning 500 results runs for a bit of time

cats_data = {'gender':[],
                'age':[],
                'weight':[],
                'breed':[],
                'drug':[],
                'outcome':[],
                'date_in':[]}
base_url = "https://api.fda.gov/animalandveterinary/event.json?search=animal.species=Cat+(animal.breed.breed_component='Domestic Shorthair'+OR+animal.breed.breed_component='Domestic Longhair')"
counter = 1
for i in range(500):
    req = requests.get(base_url)
    data = req.json()

    #validate the data, if age and weight don't exist, replace with 0. If outcome, gender, breed, and drug
    #don't exist, replace with 'Unknown'. If original_receive_date doesn't exist, replace with nan.
    try:
        cats_data['age'].append(data['results'][0]['animal']['age']['min'])
    except:
        cats_data['age'].append('0')
    
    try:
        cats_data['weight'].append(data['results'][0]['animal']['weight']['min'])
    except:
        cats_data['weight'].append('0')

    try:
        cats_data['outcome'].append(data['results'][0]['outcome'][0]['medical_status'])
    except:
        cats_data['outcome'].append('Unknown')
    
    try:
        cats_data['date_in'].append(data['results'][0]['original_receive_date'])
    except:
        cats_data['date_in'].append(np.nan)

    try:
        cats_data['gender'].append(data['results'][0]['animal']['gender'])
    except:
        cats_data['gender'].append('Unknown')
    
    try:
        cats_data['breed'].append(data['results'][0]['animal']['breed']['breed_component'])
    except:
        cats_data['breed'].append('Unknown')
    
    try:
        cats_data['drug'].append(data['results'][0]['drug'][0]['active_ingredients'][0]['name'])
    except:
        cats_data['drug'].append('Unknown')
          
    counter +=1
    #counter is converted to a string and used as a skip value for gathering random records
    str_count = str(counter)
    base_url = "https://api.fda.gov/animalandveterinary/event.json?search=animal.species=Cat+(animal.breed.breed_component='Domestic Shorthair'+OR+animal.breed.breed_component='Domestic Longhair')&skip=" + str_count

# %%
#converting the raw data in the cats dictionary to a dataframe and writing it out to a csv file

cat_df = pd.DataFrame.from_dict(cats_data)
cat_df.to_csv("cat_data.csv")

#print the info of the dataframe
cat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   gender   500 non-null    object
#  1   age      500 non-null    object
#  2   weight   500 non-null    object
#  3   breed    500 non-null    object
#  4   drug     500 non-null    object
#  5   outcome  500 non-null    object
#  6   date_in  500 non-null    object
# dtypes: object(7)
# memory usage: 27.5+ KB

# %%
#converting the age and weight columns to numerics (floats)

cat_df[["age", "weight"]] = cat_df[["age", "weight"]].apply(pd.to_numeric)
cat_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   gender   500 non-null    object
#  1   age      500 non-null    float64
#  2   weight   500 non-null    float64
#  3   breed    500 non-null    object
#  4   drug     500 non-null    object
#  5   outcome  500 non-null    object
#  6   date_in  500 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 27.5+ KB

# %%
# Extracting the year from the intake date
cat_df["date_in"] = pd.to_datetime(cat_df["date_in"])
cat_df["Year"] = cat_df['date_in'].dt.year
# Dropping intake date column
cat_df.drop('date_in', axis=1, inplace=True)
cat_df.head(15)
# Out:
#      gender   age  weight               breed                         drug  \
# 0      Male  10.0   6.350  Domestic Shorthair                     Spinosad
# 1    Female  12.0   3.130  Domestic Shorthair                    Cefovecin
# 2      Male   1.0   4.309  Domestic Shorthair                     Spinosad
# 3    Female   9.0   0.000  Domestic Shorthair                 Imidacloprid
# 4      Male   5.0   6.577  Domestic Shorthair           Maropitant Citrate
# 5      Male   2.0   5.897  Domestic Shorthair  Fluralaner Spot-On Solution
# 6      Male   8.0   8.845   Domestic Longhair                     Spinosad
# 7   Unknown   0.0   0.000       Cat (unknown)                 Imidacloprid
# 8      Male   9.0   4.309  Domestic Shorthair  Fluralaner Spot-On Solution
# 9    Female  11.0   2.722       Cat (unknown)                 Imidacloprid
# 10  Unknown   0.0   0.000       Cat (unknown)                 Praziquantel
# 11     Male   8.0   4.540   Domestic Longhair                     Spinosad
# 12  Unknown   0.0   3.180       Cat (unknown)                 Griseofulvin
# 13   Female   2.0   2.720  Domestic Shorthair                   Selamectin
# 14     Male   7.0   5.400   Domestic Longhair                Pradofloxacin
#
#              outcome  Year
# 0   Recovered/Normal  2017
# 1            Ongoing  2017
# 2   Recovered/Normal  2018
# 3    Outcome Unknown  2019
# 4            Ongoing  2019
# 5            Ongoing  2019
# 6   Recovered/Normal  2019
# 7   Recovered/Normal  2021
# 8            Ongoing  2020
# 9    Outcome Unknown  2021
# 10   Outcome Unknown  2021
# 11  Recovered/Normal  2012
# 12           Unknown  1996
# 13   Outcome Unknown  2012
# 14  Recovered/Normal  2013

# %%
# Renaming columns
cat_df.columns = ['Gender', 'Age_y', 'Weight_kg', 'Breed', 'Drug', 'Status','Year']
cat_df.head(5)
# Out:
#    Gender  Age_y  Weight_kg               Breed                Drug  \
# 0    Male   10.0      6.350  Domestic Shorthair            Spinosad
# 1  Female   12.0      3.130  Domestic Shorthair           Cefovecin
# 2    Male    1.0      4.309  Domestic Shorthair            Spinosad
# 3  Female    9.0      0.000  Domestic Shorthair        Imidacloprid
# 4    Male    5.0      6.577  Domestic Shorthair  Maropitant Citrate
#
#              Status  Year
# 0  Recovered/Normal  2017
# 1           Ongoing  2017
# 2  Recovered/Normal  2018
# 3   Outcome Unknown  2019
# 4           Ongoing  2019

# %% [markdown]
# SOME DATA FRAME WRANGLING:
# Checking out the number of distinctive values for variables

# %%
cat_df['Status'].value_counts()
# Out:
# Unknown                   168
# Outcome Unknown           102
# Recovered/Normal          101
# Ongoing                    80
# Died                       40
# Recovered with Sequela      5
# Euthanized                  4
# Name: Status, dtype: int64

# %% [markdown]
# We can change "Outcome Unknown" to "Unknown":

# %%
cat_df['Status'].replace('Outcome Unknown','Unknown', inplace=True)
cat_df['Status'].replace('Recovered/Normal','Recovered', inplace=True)
cat_df.head(10)
# Out:
#     Gender  Age_y  Weight_kg               Breed                         Drug  \
# 0     Male   10.0      6.350  Domestic Shorthair                     Spinosad
# 1   Female   12.0      3.130  Domestic Shorthair                    Cefovecin
# 2     Male    1.0      4.309  Domestic Shorthair                     Spinosad
# 3   Female    9.0      0.000  Domestic Shorthair                 Imidacloprid
# 4     Male    5.0      6.577  Domestic Shorthair           Maropitant Citrate
# 5     Male    2.0      5.897  Domestic Shorthair  Fluralaner Spot-On Solution
# 6     Male    8.0      8.845   Domestic Longhair                     Spinosad
# 7  Unknown    0.0      0.000       Cat (unknown)                 Imidacloprid
# 8     Male    9.0      4.309  Domestic Shorthair  Fluralaner Spot-On Solution
# 9   Female   11.0      2.722       Cat (unknown)                 Imidacloprid
#
#       Status  Year
# 0  Recovered  2017
# 1    Ongoing  2017
# 2  Recovered  2018
# 3    Unknown  2019
# 4    Ongoing  2019
# 5    Ongoing  2019
# 6  Recovered  2019
# 7  Recovered  2021
# 8    Ongoing  2020
# 9    Unknown  2021

# %%
cat_df['Weight_kg'].value_counts()
# Out:
# 0.000    78
# 4.990    19
# 4.536    17
# 4.540    16
# 5.440    14
#          ..
# 4.350     1
# 6.668     1
# 3.490     1
# 6.033     1
# 1.410     1
# Name: Weight_kg, Length: 177, dtype: int64

# %%
cat_df['Age_y'].value_counts()
# Out:
# 0.00     69
# 6.00     48
# 3.00     42
# 2.00     37
# 5.00     36
# 8.00     32
# 4.00     27
# 7.00     22
# 10.00    22
# 9.00     22
# 12.00    21
# 11.00    17
# 1.00     16
# 15.00    15
# 13.00    14
# 14.00     8
# 16.00     8
# 3.50      7
# 1.50      5
# 17.00     5
# 10.50     4
# 18.00     4
# 7.50      3
# 4.50      3
# 12.50     2
# 19.00     1
# 6.50      1
# 50.00     1
# 5.11      1
# 11.50     1
# 20.00     1
# 2.20      1
# 2.50      1
# 5.30      1
# 4.20      1
# 26.00     1
# Name: Age_y, dtype: int64

# %% [markdown]
# We see that 78 of the records have a weight of 0 kgs, and 69 have an age of 0 years. I'm creating a dataframe that eliminates those records. Thus, we'll restrict our attention to subjects estimated to be at least one year old, and one kg in weight.

# %%
# filter out and drop those rows HERE

# %%
# Inspecting breed category
cat_df['Breed'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# Domestic Shorthair                          189
# Domestic (unspecified)                      163
# Cat (unknown)                                66
# Domestic Mediumhair                          27
# Domestic Longhair                            26
# Cat (other)                                  10
# Mixed (Cat)                                   6
# American Shorthair                            2
# Crossbred Feline/cat                          2
# [Domestic Shorthair, Domestic Shorthair]      1
# [Cat (other), Cat (other), Cat (other)]       1
# [Siamese, Mixed (Cat)]                        1
# Abyssinian cat                                1
# [Maine Coon, Cat (other)]                     1
# Unknown                                       1
# Scottish Fold Shorthair                       1
# British cat                                   1
# [Domestic Longhair, Maine Coon]               1
# Name: Breed, dtype: int64

# %% [markdown]
# There's a lot of ambiguity among the categories, and eleven categories had two or fewer records. Trimming the data set to eliminate the latter group. Then, re-code to combine "Cat (unknown)" with "Cat (other)" and "Mixed (Cat)".

# %%
cat_df['Breed'].replace('Cat (unknown)','Unknown', inplace=True)
cat_df['Breed'].replace('Cat (other)', 'Unknown', inplace=True)
cat_df['Breed'].replace('Mixed (Cat)', 'Unknown', inplace=True)
cat_df['Breed'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas/_libs/hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# Domestic Shorthair                          189
# Domestic (unspecified)                      163
# Unknown                                      83
# Domestic Mediumhair                          27
# Domestic Longhair                            26
# American Shorthair                            2
# Crossbred Feline/cat                          2
# British cat                                   1
# Scottish Fold Shorthair                       1
# [Maine Coon, Cat (other)]                     1
# [Domestic Shorthair, Domestic Shorthair]      1
# [Siamese, Mixed (Cat)]                        1
# [Cat (other), Cat (other), Cat (other)]       1
# Abyssinian cat                                1
# [Domestic Longhair, Maine Coon]               1
# Name: Breed, dtype: int64

# %% [markdown]
# The goal - create a df that includes only the categories for which the frequency exceeds 25. Several filtering methods fail and yield the same TypeError. My naive work-around is to extract smaller dataframes from this larger one and then concatenate them. Let's see if this works:

# %%
dshort = cat_df[cat_df['Breed'] == 'Domestic Shorthair']
dshort
# Out:
#      Gender  Age_y  Weight_kg               Breed  \
# 0      Male   10.0      6.350  Domestic Shorthair
# 1    Female   12.0      3.130  Domestic Shorthair
# 2      Male    1.0      4.309  Domestic Shorthair
# 3    Female    9.0      0.000  Domestic Shorthair
# 4      Male    5.0      6.577  Domestic Shorthair
# ..      ...    ...        ...                 ...
# 493  Female    1.0      3.180  Domestic Shorthair
# 495    Male    8.0      9.979  Domestic Shorthair
# 496  Female    3.0      5.126  Domestic Shorthair
# 498  Female    2.0      5.443  Domestic Shorthair
# 499  Female   12.0      4.990  Domestic Shorthair
#
#                             Drug     Status  Year
# 0                       Spinosad  Recovered  2017
# 1                      Cefovecin    Ongoing  2017
# 2                       Spinosad  Recovered  2018
# 3                   Imidacloprid    Unknown  2019
# 4             Maropitant Citrate    Ongoing  2019
# ..                           ...        ...   ...
# 493                 Praziquantel  Recovered  2017
# 495                   Selamectin    Unknown  2017
# 496                     Spinosad  Recovered  2016
# 498  Phytosphingosine Salicyloyl    Ongoing  2018
# 499                   Nitenpyram    Unknown  2018
#
# [189 rows x 7 columns]

# %%
dlong = cat_df[cat_df['Breed'] == 'Domestic Longhair']
dlong
# Out:
#       Gender  Age_y  Weight_kg              Breed  \
# 6       Male    8.0      8.845  Domestic Longhair
# 11      Male    8.0      4.540  Domestic Longhair
# 14      Male    7.0      5.400  Domestic Longhair
# 35      Male   15.0      5.897  Domestic Longhair
# 69    Female   10.0      3.900  Domestic Longhair
# 70      Male   12.0      1.910  Domestic Longhair
# 93      Male    2.0      5.443  Domestic Longhair
# 99    Female    6.0      4.128  Domestic Longhair
# 102   Female    6.0      3.266  Domestic Longhair
# 108   Female    7.0      4.990  Domestic Longhair
# 137   Female   13.0      5.126  Domestic Longhair
# 138   Female   15.0      2.722  Domestic Longhair
# 146     Male    4.0      5.440  Domestic Longhair
# 159     Male    8.0      4.536  Domestic Longhair
# 222     Male   12.0      7.711  Domestic Longhair
# 240     Male    5.0      5.080  Domestic Longhair
# 252     Male    3.0      5.216  Domestic Longhair
# 262   Female   15.0      3.311  Domestic Longhair
# 311     Male    5.0      5.897  Domestic Longhair
# 317   Female    3.0      4.218  Domestic Longhair
# 366  Unknown    0.0      0.000  Domestic Longhair
# 390   Female   13.0      6.400  Domestic Longhair
# 417     Male    3.0      4.536  Domestic Longhair
# 429   Female    8.0      5.440  Domestic Longhair
# 449   Female   15.0      4.990  Domestic Longhair
# 468     Male   17.0      4.808  Domestic Longhair
#
#                               Drug                  Status  Year
# 6                         Spinosad               Recovered  2019
# 11                        Spinosad               Recovered  2012
# 14                   Pradofloxacin               Recovered  2013
# 35                        Spinosad               Recovered  2015
# 69                        Spinosad  Recovered with Sequela  2012
# 70                      Selamectin                 Unknown  2014
# 93                        Spinosad                 Ongoing  2016
# 99                        Spinosad               Recovered  2017
# 102                     Selamectin                 Ongoing  2019
# 108                     Nitenpyram               Recovered  2012
# 137                    Robenacoxib                 Ongoing  2021
# 138    Fluralaner Spot-On Solution                 Ongoing  2021
# 146                       Spinosad               Recovered  2013
# 159                       Spinosad               Recovered  2016
# 222                       Spinosad               Recovered  2014
# 240                   Imidacloprid                 Unknown  2015
# 252                   Imidacloprid                 Unknown  2018
# 262                       Spinosad               Recovered  2014
# 311                     Nitenpyram                 Ongoing  2019
# 317    Fluralaner Spot-On Solution               Recovered  2020
# 366    Fluralaner Spot-On Solution                 Ongoing  2017
# 390                      Cefovecin                 Unknown  2013
# 417                     Nitenpyram               Recovered  2018
# 429                     Nitenpyram                 Unknown  2014
# 449  Fluralaner/Moxidectin Spot-On                 Ongoing  2021
# 468                   Eprinomectin                 Unknown  2020

# %%
dmed = cat_df[cat_df['Breed'] == 'Domestic Mediumhair']
dmed
# Out:
#      Gender  Age_y  Weight_kg                Breed  \
# 38   Female    3.0      6.396  Domestic Mediumhair
# 44     Male    6.0      7.484  Domestic Mediumhair
# 45   Female    0.0      0.000  Domestic Mediumhair
# 49   Female    7.0      4.445  Domestic Mediumhair
# 53     Male    6.0      5.440  Domestic Mediumhair
# 72     Male    3.0      5.130  Domestic Mediumhair
# 105  Female    6.0      5.897  Domestic Mediumhair
# 106    Male    3.0      4.354  Domestic Mediumhair
# 135    Male    7.0      5.180  Domestic Mediumhair
# 145    Male    8.0      4.540  Domestic Mediumhair
# 163  Female    3.0      3.538  Domestic Mediumhair
# 168    Male    9.0      1.021  Domestic Mediumhair
# 171  Female    2.0      4.853  Domestic Mediumhair
# 253  Female    3.0      4.536  Domestic Mediumhair
# 259  Female   18.0      3.266  Domestic Mediumhair
# 261    Male    3.0      5.220  Domestic Mediumhair
# 292    Male    0.0      5.670  Domestic Mediumhair
# 305  Female   15.0      3.946  Domestic Mediumhair
# 310    Male   14.0      3.175  Domestic Mediumhair
# 322    Male   14.0      6.690  Domestic Mediumhair
# 326    Male    2.0      5.829  Domestic Mediumhair
# 361  Female   16.0      0.000  Domestic Mediumhair
# 368  Female   10.0      1.130  Domestic Mediumhair
# 389  Female    4.0      1.810  Domestic Mediumhair
# 414  Female    1.0      3.175  Domestic Mediumhair
# 440  Female    8.0      3.266  Domestic Mediumhair
# 490    Male    3.0      3.000  Domestic Mediumhair
#
#                             Drug      Status  Year
# 38                      Spinosad   Recovered  2016
# 44   Fluralaner Spot-On Solution     Ongoing  2018
# 45                    Selamectin     Ongoing  2018
# 49                 Buprenorphine     Ongoing  2020
# 53                      Spinosad   Recovered  2013
# 72                    Selamectin     Unknown  2014
# 105                 Praziquantel     Unknown  2021
# 106  Fluralaner Spot-On Solution     Ongoing  2020
# 135                   Selamectin     Ongoing  2018
# 145                     Spinosad  Euthanized  2013
# 163  Fluralaner Spot-On Solution     Ongoing  2017
# 168                  Robenacoxib     Ongoing  2018
# 171  Fluralaner Spot-On Solution     Ongoing  2019
# 253         Selamectin;Sarolaner     Unknown  2020
# 259                 Cyclosporine     Ongoing  2021
# 261                   Emodepside     Unknown  2012
# 292                     Spinosad   Recovered  2014
# 305                 Praziquantel   Recovered  2015
# 310                   Selamectin     Ongoing  2018
# 322                Buprenorphine   Recovered  2018
# 326         Selamectin;Sarolaner     Unknown  2019
# 361                   Selamectin     Ongoing  2016
# 368                   Selamectin   Recovered  2015
# 389                     Spinosad   Recovered  2013
# 414                     Spinosad   Recovered  2016
# 440                Buprenorphine        Died  2015
# 490                    Cefovecin     Ongoing  2020

# %%
dunsp = cat_df[cat_df['Breed'] == 'Domestic (unspecified)']
dunsp
# Out:
#       Gender  Age_y  Weight_kg                   Breed  \
# 16      Male    2.0       6.35  Domestic (unspecified)
# 17      Male   10.0       5.50  Domestic (unspecified)
# 20      Male   15.0       8.16  Domestic (unspecified)
# 21    Female   17.0       3.18  Domestic (unspecified)
# 22      Male    2.0       4.99  Domestic (unspecified)
# ..       ...    ...        ...                     ...
# 479  Unknown    9.0       7.26  Domestic (unspecified)
# 480    Mixed    0.0       0.00  Domestic (unspecified)
# 483   Female   10.0       5.22  Domestic (unspecified)
# 485     Male    6.0       7.26  Domestic (unspecified)
# 487     Male    9.0       5.90  Domestic (unspecified)
#
#                        Drug   Status  Year
# 16         Pyrantel Pamoate  Unknown  2007
# 17             Enrofloxacin  Unknown  2006
# 20             Cyclosporine  Unknown  2011
# 21   Ketamine Hydrochloride  Unknown  2004
# 22                Lufenuron  Unknown  1996
# ..                      ...      ...   ...
# 479               Carprofen  Unknown  1998
# 480              Selamectin  Unknown  2010
# 483               Carprofen  Unknown  2000
# 485              Selamectin  Unknown  2005
# 487        Cefovecin Sodium  Unknown  2009
#
# [163 rows x 7 columns]

# %%
unkn = cat_df[cat_df['Breed'] == 'Unknown']
unkn
# Out:
#       Gender  Age_y  Weight_kg    Breed                      Drug     Status  \
# 7    Unknown    0.0      0.000  Unknown              Imidacloprid  Recovered
# 9     Female   11.0      2.722  Unknown              Imidacloprid    Unknown
# 10   Unknown    0.0      0.000  Unknown              Praziquantel    Unknown
# 12   Unknown    0.0      3.180  Unknown              Griseofulvin    Unknown
# 18   Unknown    3.0      3.180  Unknown    Ketamine Hydrochloride    Unknown
# ..       ...    ...        ...      ...                       ...        ...
# 482   Female    3.0      5.220  Unknown              Imidacloprid    Unknown
# 486     Male    0.0      0.000  Unknown  Emodepside, Praziquantel    Unknown
# 492  Unknown    0.0      6.350  Unknown                Selamectin    Ongoing
# 494  Unknown    0.0      6.169  Unknown                Nitenpyram    Unknown
# 497  Unknown    0.0      0.000  Unknown              Praziquantel    Unknown
#
#      Year
# 7    2021
# 9    2021
# 10   2021
# 12   1996
# 18   1988
# ..    ...
# 482  2015
# 486  2009
# 492  2016
# 494  2015
# 497  2017
#
# [83 rows x 7 columns]

# %%
frames = [dshort, dlong, dmed, dunsp, unkn]

# %%
cat = pd.concat(frames)
cat
# Out:
#       Gender  Age_y  Weight_kg               Breed                      Drug  \
# 0       Male   10.0      6.350  Domestic Shorthair                  Spinosad
# 1     Female   12.0      3.130  Domestic Shorthair                 Cefovecin
# 2       Male    1.0      4.309  Domestic Shorthair                  Spinosad
# 3     Female    9.0      0.000  Domestic Shorthair              Imidacloprid
# 4       Male    5.0      6.577  Domestic Shorthair        Maropitant Citrate
# ..       ...    ...        ...                 ...                       ...
# 482   Female    3.0      5.220             Unknown              Imidacloprid
# 486     Male    0.0      0.000             Unknown  Emodepside, Praziquantel
# 492  Unknown    0.0      6.350             Unknown                Selamectin
# 494  Unknown    0.0      6.169             Unknown                Nitenpyram
# 497  Unknown    0.0      0.000             Unknown              Praziquantel
#
#         Status  Year
# 0    Recovered  2017
# 1      Ongoing  2017
# 2    Recovered  2018
# 3      Unknown  2019
# 4      Ongoing  2019
# ..         ...   ...
# 482    Unknown  2015
# 486    Unknown  2009
# 492    Ongoing  2016
# 494    Unknown  2015
# 497    Unknown  2017
#
# [488 rows x 7 columns]

# %%
cat.drop(cat.index[cat['Age_y'] == 0], inplace = True)
print(cat)
# Out:
#      Gender  Age_y  Weight_kg               Breed                Drug  \
# 0      Male  10.00      6.350  Domestic Shorthair            Spinosad
# 1    Female  12.00      3.130  Domestic Shorthair           Cefovecin
# 2      Male   1.00      4.309  Domestic Shorthair            Spinosad
# 3    Female   9.00      0.000  Domestic Shorthair        Imidacloprid
# 4      Male   5.00      6.577  Domestic Shorthair  Maropitant Citrate
# ..      ...    ...        ...                 ...                 ...
# 444  Female  11.00      5.262             Unknown        Praziquantel
# 459    Male   1.00      7.620             Unknown        Imidacloprid
# 462    Male   5.11      6.260             Unknown            Spinosad
# 471  Female  18.00      3.860             Unknown            Spinosad
# 482  Female   3.00      5.220             Unknown        Imidacloprid
#
#         Status  Year
# 0    Recovered  2017
# 1      Ongoing  2017
# 2    Recovered  2018
# 3      Unknown  2019
# 4      Ongoing  2019
# ..         ...   ...
# 444    Unknown  2016
# 459  Recovered  2016
# 462  Recovered  2017
# 471  Recovered  2013
# 482    Unknown  2015
#
# [420 rows x 7 columns]

# %%
cat.drop(cat.index[cat['Weight_kg'] == 0], inplace = True)
print(cat)
# Out:
#      Gender  Age_y  Weight_kg               Breed  \
# 0      Male  10.00      6.350  Domestic Shorthair
# 1    Female  12.00      3.130  Domestic Shorthair
# 2      Male   1.00      4.309  Domestic Shorthair
# 4      Male   5.00      6.577  Domestic Shorthair
# 5      Male   2.00      5.897  Domestic Shorthair
# ..      ...    ...        ...                 ...
# 444  Female  11.00      5.262             Unknown
# 459    Male   1.00      7.620             Unknown
# 462    Male   5.11      6.260             Unknown
# 471  Female  18.00      3.860             Unknown
# 482  Female   3.00      5.220             Unknown
#
#                             Drug     Status  Year
# 0                       Spinosad  Recovered  2017
# 1                      Cefovecin    Ongoing  2017
# 2                       Spinosad  Recovered  2018
# 4             Maropitant Citrate    Ongoing  2019
# 5    Fluralaner Spot-On Solution    Ongoing  2019
# ..                           ...        ...   ...
# 444                 Praziquantel    Unknown  2016
# 459                 Imidacloprid  Recovered  2016
# 462                     Spinosad  Recovered  2017
# 471                     Spinosad  Recovered  2013
# 482                 Imidacloprid    Unknown  2015
#
# [398 rows x 7 columns]

# %%
cat['Drug'].value_counts()
# Out:
# Selamectin                                                                       92
# Spinosad                                                                         67
# Fluralaner Spot-On Solution                                                      30
# Nitenpyram                                                                       28
# Imidacloprid                                                                     25
#                                                                                  ..
# Hexetidine                                                                        1
# Marbofloxacin                                                                     1
# Ear Cleansers/Astringents                                                         1
# Ivermectin                                                                        1
# Amoxicillin As Amoxicillin Trihydrate; Clavulanate Potassium ( K-Clavulanate)     1
# Name: Drug, Length: 80, dtype: int64

# %% [markdown]
# At this point, we now have about 400 records. I want to filter out all of the records for which the abundance of a drug is >= 10

# %%
catdf = cat.groupby('Drug').filter(lambda x: (x['Drug'].count()>=10).any())

# %%
catdf
# Out:
#      Gender  Age_y  Weight_kg               Breed  \
# 0      Male  10.00      6.350  Domestic Shorthair
# 2      Male   1.00      4.309  Domestic Shorthair
# 5      Male   2.00      5.897  Domestic Shorthair
# 8      Male   9.00      4.309  Domestic Shorthair
# 13   Female   2.00      2.720  Domestic Shorthair
# ..      ...    ...        ...                 ...
# 444  Female  11.00      5.262             Unknown
# 459    Male   1.00      7.620             Unknown
# 462    Male   5.11      6.260             Unknown
# 471  Female  18.00      3.860             Unknown
# 482  Female   3.00      5.220             Unknown
#
#                             Drug     Status  Year
# 0                       Spinosad  Recovered  2017
# 2                       Spinosad  Recovered  2018
# 5    Fluralaner Spot-On Solution    Ongoing  2019
# 8    Fluralaner Spot-On Solution    Ongoing  2020
# 13                    Selamectin    Unknown  2012
# ..                           ...        ...   ...
# 444                 Praziquantel    Unknown  2016
# 459                 Imidacloprid  Recovered  2016
# 462                     Spinosad  Recovered  2017
# 471                     Spinosad  Recovered  2013
# 482                 Imidacloprid    Unknown  2015
#
# [240 rows x 7 columns]

# %%
catdf['Drug'].value_counts()
# Out:
# Selamectin                     73
# Spinosad                       59
# Fluralaner Spot-On Solution    27
# Nitenpyram                     21
# Imidacloprid                   18
# Meloxicam                      15
# Praziquantel                   15
# Lufenuron                      12
# Name: Drug, dtype: int64
